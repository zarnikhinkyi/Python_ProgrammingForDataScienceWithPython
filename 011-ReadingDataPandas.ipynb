# %%
import pandas as pd
df =pd.read_csv('abc_ltd.csv')
df
# Out:
#         Name   Department   Salary
# 0    Win Win  Engineering   250000
# 1  Aung Aung      Finance   200000
# 2      Ni Ni           HR  1500000
# 3   Maung Ba      Finance   205000
# 4  Maung Hla           HR   150000

# %%
df=pd.read_csv('abc_ltd.csv', index_col=0)
df
# Out:
#             Department   Salary
# Name
# Win Win    Engineering   250000
# Aung Aung      Finance   200000
# Ni Ni               HR  1500000
# Maung Ba       Finance   205000
# Maung Hla           HR   150000

# %%
jdf=pd.read_json('xyz_ltd.json')
jdf
# Out:
#         Name   Department  Salary
# 0    Win Win  Engineering  250000
# 1  Sein Sein           IT  300000
# 2  Aung Aung      Finance  200000
# 3      Ni Ni           HR  150000
# 4   Maung Ba      Finance  205000
# 5  Maung Hla           HR  155000

# %%
# !pip install pysqlite3
# Out:
# ...
#   Using cached pysqlite3-0.4.7.tar.gz (40 kB)
# ...
#   Running setup.py clean for pysqlite3
# Failed to build pysqlite3
# ...
#     Running setup.py install for pysqlite3: started
#     Running setup.py install for pysqlite3: finished with status 'done'
# ...
#   WARNING: Legacy build of wheel for 'pysqlite3' created no files.
# ...

# %%
import sqlite3 as sql

# %%
conn =sql.connect('abc_ltd.db')
conn

# %%
ddf = pd.read_sql_query('SELECT * FROM employee', conn)
ddf
# Out:
#    id       name   department  salary
# 0   1    Win Win  Engineering  250000
# 1   2  Sein Sein           IT  300000
# 2   3  Aung Aung      Finance  200000
# 3   4      Ni Ni           HR  150000
# 4   5   Maung Ba      Finance  205000
# 5   6  Maung Hla           HR  150000

# %%
ddf = pd.read_sql_query('SELECT * FROM employee', conn)
ddf
# Out:
#    id       name   department  salary
# 0   1    Win Win  Engineering  250000
# 1   2  Sein Sein           IT  300000
# 2   3  Aung Aung      Finance  200000
# 3   4      Ni Ni           HR  150000
# 4   5   Maung Ba      Finance  205000
# 5   6  Maung Hla           HR  150000
# 6   7      Ko Ko           IT  250000

# %%
ddf.set_index('id',inplace=True)
ddf
# Out:
#          name   department  salary
# id
# 1     Win Win  Engineering  250000
# 2   Sein Sein           IT  300000
# 3   Aung Aung      Finance  200000
# 4       Ni Ni           HR  150000
# 5    Maung Ba      Finance  205000
# 6   Maung Hla           HR  150000
# 7       Ko Ko           IT  250000

# %%
ddf=ddf.reset_index()
ddf
# Out:
#    id       name   department  salary
# 0   1    Win Win  Engineering  250000
# 1   2  Sein Sein           IT  300000
# 2   3  Aung Aung      Finance  200000
# 3   4      Ni Ni           HR  150000
# 4   5   Maung Ba      Finance  205000
# 5   6  Maung Hla           HR  150000
# 6   7      Ko Ko           IT  250000

# %%
ddf=ddf.append({'id':8,'name':'Kyaw Kyaw','department':'Management','salary':50000},ignore_index=True)
ddf
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9048\1215221442.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ddf=ddf.append({'id':8,'name':'Kyaw Kyaw','department':'Management','salary':50000},ignore_index=True)
#    id       name   department  salary
# 0   1    Win Win  Engineering  250000
# 1   2  Sein Sein           IT  300000
# 2   3  Aung Aung      Finance  200000
# 3   4      Ni Ni           HR  150000
# 4   5   Maung Ba      Finance  205000
# 5   6  Maung Hla           HR  150000
# 6   7      Ko Ko           IT  250000
# 7   8  Kyaw Kyaw   Management   50000

# %%
ddf.to_sql('newnew_employee', conn)
# Out:
# 8

# %%
df
# Out:
#         Name   Department   Salary
# 0    Win Win  Engineering   250000
# 1  Aung Aung      Finance   200000
# 2      Ni Ni           HR  1500000
# 3   Maung Ba      Finance   205000
# 4  Maung Hla           HR   150000

# %%
df.to_csv('new_abc_ltd.csv')

# %%
jdf.to_json('new_xyz_ltd.json')
